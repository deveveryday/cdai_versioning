# %%
from calculate import calculate_percentage, add_percentage, reduce_percentage

# desenvolva inicialmente um código em Python capaz de
# resolver os seguintes cálculos:
#• 10% de 500
#• 25% de 800
#• 38% de 260

shop_cart = [(500, 10), (800, 25), (260, 38)]

calculate_percentage(shop_cart)
print("")
add_percentage(shop_cart)
print("")
reduce_percentage(shop_cart)
# Out:
# $50.0
# $200.0
# $98.8
#
# $550.0
# $1000.0
# $358.8
#
# $450.0
# $600.0
# $161.2
