# %%
def calculate_percentage(price, percentual):
    print(f"${price * (percentual / 100)}")

# %%
values = [(500, 10), (800, 25), (260, 38)]

for value in values:
  calculate_percentage(value[0], value[1])
